# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **sports or athletics** (see below) for the region of **Pine Bush, New York, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Pine Bush, New York, United States** to Ann Arbor, USA. In that case at least one source file must be about **Pine Bush, New York, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Pine Bush, New York, United States** and **sports or athletics**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **sports or athletics**?  For this category we are interested in sporting events or athletics broadly, please feel free to creatively interpret the category when building your research question!
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
import seaborn as sns

# use the 'seaborn-colorblind' style
plt.style.use('seaborn-dark')

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-dark-palette',
#  'seaborn-poster',
#  'grayscale',
#  'seaborn-white',
#  'fivethirtyeight',
#  'seaborn-notebook',
#  'seaborn-pastel',
#  'classic',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'bmh',
#  'seaborn-ticks',
#  'dark_background',
#  'seaborn-muted',
#  'seaborn-talk',
#  'seaborn-bright',
#  'ggplot',
#  'seaborn-paper',
#  'seaborn-colorblind']

# %%
# get the data
mets = pd.read_csv('sportsref_mets.csv')
yanks = pd.read_csv('sportsref_download.csv')

# %%
# check how far back the yearly data goes..
yanks_first_year, mets_first_year = yanks['Year'].min(), mets['Year'].min()

# cut back data to match years
yanks = yanks[yanks['Year'] >= mets_first_year]
yanks
# Out:
#     Year                Tm       Lg    G    W   L  Ties   W-L%  pythW-L%  \
# 0   2017  New York Yankees  AL East  162   91  71     0  0.562     0.618
# 1   2016  New York Yankees  AL East  162   84  78     0  0.519     0.485
# 2   2015  New York Yankees  AL East  162   87  75     0  0.537     0.541
# 3   2014  New York Yankees  AL East  162   84  78     0  0.519     0.478
# 4   2013  New York Yankees  AL East  162   85  77     0  0.525     0.485
# 5   2012  New York Yankees  AL East  162   95  67     0  0.586     0.584
# 6   2011  New York Yankees  AL East  162   97  65     0  0.599     0.624
# 7   2010  New York Yankees  AL East  162   95  67     0  0.586     0.597
# 8   2009  New York Yankees  AL East  162  103  59     0  0.636     0.588
# 9   2008  New York Yankees  AL East  162   89  73     0  0.549     0.537
# 10  2007  New York Yankees  AL East  162   94  68     0  0.580     0.599
# 11  2006  New York Yankees  AL East  162   97  65     0  0.599     0.587
# ...

# %%
# clean up 'Manager' columns for both Yankees and Mets
yanks['Managers'] = yanks['Managers'].str.replace(r'\(.*\)', '')
mets['Managers'] = mets['Managers'].str.replace(r'\(.*\)', '')

# groupby managers and get info about them
yank_mans = yanks.groupby('Managers')['W-L%'].agg({'Avg': lambda x: x.mean(), '# Years': lambda x: x.count()})

# again for mets..
met_mans = mets.groupby('Managers')['W-L%'].agg({'Avg': lambda x: x.mean(), '# Years': lambda x: x.count()})

# plot Avg W-L% vs #Years
plt.figure()
plt.plot(met_mans['# Years'], met_mans['Avg'], 'o', color='orange', label='Mets')
plt.plot(yank_mans['# Years'], yank_mans['Avg'], 'o', color='blue', alpha=0.5, label='Yankees')

plt.legend(loc=4)
plt.title('Managers Number of Years vs. Average Win-Loss Percentage\n For the Yankees and the Mets')
plt.xlabel('# Years as Manager')
plt.ylabel('Win-Loss %')
plt.xlim(0, 13.5)
# plt.ylim(0.25, 0.75)
# Out:
# <img src="data:image/png;base64,...">
# (0, 13.5)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
ax1 = plt.subplot(111)
# ax1.plot(mets['Year'], mets['W-L%'].rolling(window=10).mean(), 
#          '-', label='Mets', color='orange', alpha=0.9)
ax1.plot(yanks['Year'], yanks['W-L%'].rolling(window=10).mean(), 
         '-', 
         label='Win_loss %', 
         color='navy', 
         alpha=0.7)

ax1.legend(loc=2)
ax1.set_ylabel('Win-Loss % (10-year running mean)')
ax1.set_title('Winning Stats of New York Major League Baseball Teams (1962-2017)')
# Out:
# <img src="data:image/png;base64,...">

# %%
ax2 = ax1.twinx()
ax2.plot(yanks['Year'], yanks['Attendance'].rolling(10).mean(),
         'o', 
         color='lightblue', 
         alpha=0.9,
         label='Attendance')
# ax2.plot(mets['Year'], mets['Attendance'].rolling(10).mean(), 'o', color='darkorange', alpha=0.5)
ax2.set_ylabel('Attendance')
ax2.legend(loc=4)

# %%
plt.subplot(222)
plt.plot(yanks['10yr Mean'], yanks['Attendance'], 'o', color='navy')

# %%
# managers
y_managers = yanks['Managers'].unique()
y_managers = [man for man in y_managers if yanks.groupby('Managers')['Year'].count().loc[man] > 5]

m_managers = mets['Managers'].unique()
m_managers = [man for man in m_managers if mets.groupby('Managers')['Year'].count().loc[man] > 5]

# %%
### yanks['WL Mean'] = yanks['W-L%'].rolling(window=5).mean()
yanks.head()

# %%
plt.figure()

yanks['10yr Mean'] = yanks['W-L%'].rolling(10).mean()
mets['10yr Mean'] = mets['W-L%'].rolling(10).mean()

yanks['5yr Mean'] = yanks['W-L%'].rolling(5).mean()
mets['5yr Mean'] = mets['W-L%'].rolling(5).mean()


plt.plot(yanks['Year'], yanks['10yr Mean'], '-', label='Yankees', color='navy', alpha=0.7)
plt.plot(mets['Year'], mets['10yr Mean'], '-', label='Mets', color='orange', alpha=0.7)

blue, red = 0.0, 0.0
for yank in y_managers:
    stats = yanks[yanks['Managers'] == yank]
    last_year = stats['Year'].max()
    blue += 0.25
    plt.plot(last_year, stats['W-L%'].mean(), 'o', label=yank, color='navy')
    
for met in m_managers:
    stats = mets[mets['Managers'] == met]
    last_year = stats['Year'].max()
    red += 0.25
    plt.plot(last_year, stats['W-L%'].mean(), 'o', label=met, color='orange')

    
plt.legend()
plt.xlabel('Year')
# Out:
# <img src="data:image/png;base64,...">

# %%
# Out:
# None

# %%
# Does Attentdance increase when the teams are doing well?

fig = plt.figure()
plt.plot(yanks['10yr Mean'], yanks['Attendance'], 'o', color='navy')
# plt.plot(mets['10yr Mean'], mets['Attendance'], 'o', color='orange')
# Out:
# <img src="data:image/png;base64,...">
